# %% [markdown]
# Confronto dei risultati delle tecniche utilizzate

# %%
import import_ipynb
import nbimporter
from utils import Grafico_Confronto_ML, Grafico_Confronto_ML_NN
from Knn import knn3Sec, knn30Sec
# Out:
# c:\Users\romeo\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\romeo\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Accuratezza: 0.2550
# Precision: 0.2356
# Recall: 0.2667
# F1-score: 0.2416
# F2-score: 0.2542
# Accuratezza: 0.6600
# Precision: 0.6767
# Recall: 0.6707
# F1-score: 0.6675
# F2-score: 0.6681
# Migliori iperparametri trovati: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Accuratezza: 0.7100
# Precision: 0.7264
# Recall: 0.7182
# ...

# %%
import import_ipynb
import nbimporter
from Knn import knn3Sec, knn30Sec
from LogisticRegression import logisticRegression3Sec, logisticRegression30Sec
from RandomForest import randomForest3Sec, randomForest30Sec
from svm import svm3Sec, svm30Sec
from nn import nn1,nn2,nn3,nn4
from utils import Grafico_Confronto_ML, Grafico_Confronto_ML_NN
# Out:
# c:\Users\romeo\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\romeo\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Accuratezza: 0.2550
# Precision: 0.2356
# Recall: 0.2667
# F1-score: 0.2416
# F2-score: 0.2542
# Accuratezza: 0.6600
# Precision: 0.6767
# Recall: 0.6707
# F1-score: 0.6675
# F2-score: 0.6681
# Migliori iperparametri trovati: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Accuratezza: 0.7100
# Precision: 0.7264
# Recall: 0.7182
# ...

# %% [markdown]
# Grafico confronto tecniche di ML 30 secondi

# %%
Grafico_Confronto_ML(knn30Sec=0.50, logisticRegression30Sec= 0.70,randomForest30Sec=0.80,svm30Sec=0.90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Grafico_Confronto_ML(knn30Sec=0.50, logisticRegression30Sec= 0.70,randomForest30Sec=0.80,svm30Sec=0.90)
#
# TypeError: Grafico_Confronto_ML() got an unexpected keyword argument 'knn30Sec'

# %% [markdown]
# Grafico confronto tecniche di ML 3 secondi

# %%
Grafico_Confronto_ML(knn3Sec, logisticRegression3Sec,randomForest3Sec,svm3Sec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Grafico_Confronto_ML(knn3Sec, logisticRegression3Sec,randomForest3Sec,svm3Sec)
#
# NameError: name 'knn3Sec' is not defined

# %% [markdown]
# Grafico confronto tecniche di ML 3 secondi e NN
